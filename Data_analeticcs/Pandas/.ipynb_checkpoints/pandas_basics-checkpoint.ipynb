# %%
import numpy as np
import pandas as pd

# %%
# pandas series label (index)
lables = ['a','b','c']
my_list = [10,20,30]
arr = [10,20,30]
my_dict = {1:10 , 2:20 , 3:30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list, index = lables)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_dict)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64
