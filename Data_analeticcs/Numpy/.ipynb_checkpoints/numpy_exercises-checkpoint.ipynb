# %%
import numpy as np

# %%
data = np.array([
                [18,85,78],
                [19,92,88],
                [17,76,95],
                [18,65,70],
                [20,90,85]
                         ])
